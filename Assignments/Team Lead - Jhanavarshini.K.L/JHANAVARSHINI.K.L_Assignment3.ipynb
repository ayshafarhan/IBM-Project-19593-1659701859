# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# flower1.h4/  flowers/  Flowers-Dataset.zip

# %%
cd /content/sample_data/K.L.J CNN
# Out:
# /content/sample_data/K.L.J CNN

# %%
ls
# Out:
# flower1.h4/  flowers/  Flowers-Dataset.zip

# %%
pwd
# Out:
# '/content/sample_data/K.L.J CNN'

# %%
# !unzip Flowers-Dataset.zip

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
test_data = ImageDataGenerator(rescale = 1./255)

# %%
x_train = train_data.flow_from_directory(r"/content/sample_data/K.L.J CNN/flowers", target_size = (64,64), class_mode = "categorical", batch_size = 64)
# Out:
# Found 4317 images belonging to 5 classes.

# %%
x_test = test_data.flow_from_directory(r"/content/sample_data/K.L.J CNN/flowers", target_size = (64,64), class_mode = "categorical", batch_size = 64)
# Out:
# Found 4317 images belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Dense,Flatten

# %%
model = Sequential()

# %%
model.add(Convolution2D(32,(3,3), activation = "relu", input_shape = (64,64,3)))

# %%
model.add(MaxPooling2D(pool_size = (2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(300, activation = "relu"))

# %%
model.add(Dense(4, activation ="relu"))

# %%
model.compile(loss = "categorical_crossentrophy", metrics = ["accuracy"], optimizer = "adam" )

# %%
len(x_train)
# Out:
# 68

# %%
model.save("flower1.h4")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import tensorflow as tf
image_path = '/content/sample_data/K.L.J CNN/flowers/sunflower/10386503264_e05387e1f7_m.jpg'
image_loaded = tf.keras.utils.load_img(image_path)
image_loaded
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x231 at 0x7F31E825E9D0>
